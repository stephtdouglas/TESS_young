# %%
import os, sys

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import astropy.io.ascii as at

# %%
from analyze_cluster_output import plot_periodcolor_histogram, mass_to_bp_rp

# %%
ax = plot_periodcolor_histogram(clean_limit=0,to_plot_indiv=False)

# %%
mod_dir = os.path.expanduser("~/Dropbox/Models")

# %%
for age in [30,40,50,60,70]:
    plt.figure(figsize=(15,4))
    for i, model in enumerate(["ZeroTorque","Mattea2015","Mattea2022"]):
        ax = plt.subplot(1,3,i+1)
        modfile = os.path.join(mod_dir,f"UpSco_{model}/UpSco_{model}_000{age}Myr.txt")
        print(modfile)
        mod = at.read(modfile,names=["mass","period"])
        print(mod[:5])
        _ = plot_periodcolor_histogram(clean_limit=0,to_plot_indiv=False,ax=ax)
        mod_bprp = mass_to_bp_rp(mod["mass"])
        ax.plot(mod_bprp,mod["period"],'*',ms=4,alpha=0.75)
        ax.set_title(model)
    plt.suptitle(f"t = {age} Myr")
    plt.savefig(f"plots/matt_models_{age:03d}Myr.png")
# Out:
# /Users/douglste/Dropbox/Models/UpSco_ZeroTorque/UpSco_ZeroTorque_00030Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.90586723
#     1.2012  1.3578028
# 0.28535998  1.5296523
#   0.582192 0.17988668
#  1.2705761  1.2463376
# /Users/douglste/Dropbox/Models/UpSco_Mattea2015/UpSco_Mattea2015_00030Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.90586723
#     1.2012  1.3578028
# 0.28535998  1.5296523
#   0.582192 0.17988668
#  1.2705761  1.2463376
# /Users/douglste/Dropbox/Models/UpSco_Mattea2022/UpSco_Mattea2022_00030Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.90586723
#     1.2012  1.3578028
# 0.28535998  1.5296523
#   0.582192 0.17988668
#  1.2705761  1.2463376
# /Users/douglste/Dropbox/Models/UpSco_ZeroTorque/UpSco_ZeroTorque_00040Myr.txt
#    mass      period
# ---------- ----------
#    0.30328  0.7639952
#     1.2012   1.478912
# 0.28535998  1.2894278
#   0.582192 0.15425053
#  1.2705761  1.2454066
# /Users/douglste/Dropbox/Models/UpSco_Mattea2015/UpSco_Mattea2015_00040Myr.txt
#    mass      period
# ---------- ----------
#    0.30328  0.7639952
#     1.2012   1.478912
# 0.28535998  1.2894278
#   0.582192 0.15425053
#  1.2705761  1.2454066
# /Users/douglste/Dropbox/Models/UpSco_Mattea2022/UpSco_Mattea2022_00040Myr.txt
#    mass      period
# ---------- ----------
#    0.30328  0.7639952
#     1.2012   1.478912
# 0.28535998  1.2894278
#   0.582192 0.15425053
#  1.2705761  1.2454066
# /Users/douglste/Dropbox/Models/UpSco_ZeroTorque/UpSco_ZeroTorque_00050Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.67775615
#     1.2012  1.5528443
# 0.28535998  1.1435452
#   0.582192 0.13829043
#  1.2705761  1.2489491
# /Users/douglste/Dropbox/Models/UpSco_Mattea2015/UpSco_Mattea2015_00050Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.67775615
#     1.2012  1.5528443
# 0.28535998  1.1435452
#   0.582192 0.13829043
#  1.2705761  1.2489491
# /Users/douglste/Dropbox/Models/UpSco_Mattea2022/UpSco_Mattea2022_00050Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.67775615
#     1.2012  1.5528443
# 0.28535998  1.1435452
#   0.582192 0.13829043
#  1.2705761  1.2489491
# /Users/douglste/Dropbox/Models/UpSco_ZeroTorque/UpSco_ZeroTorque_00060Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.61864193
#     1.2012  1.6213967
# 0.28535998  1.0433165
#   0.582192 0.12726443
#  1.2705761  1.2613842
# /Users/douglste/Dropbox/Models/UpSco_Mattea2015/UpSco_Mattea2015_00060Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.61864193
#     1.2012  1.6213967
# 0.28535998  1.0433165
#   0.582192 0.12726443
#  1.2705761  1.2613842
# /Users/douglste/Dropbox/Models/UpSco_Mattea2022/UpSco_Mattea2022_00060Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.61864193
#     1.2012  1.6213967
# 0.28535998  1.0433165
#   0.582192 0.12726443
#  1.2705761  1.2613842
# /Users/douglste/Dropbox/Models/UpSco_ZeroTorque/UpSco_ZeroTorque_00070Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.57435709
#     1.2012  1.6924892
# 0.28535998 0.96807293
#   0.582192 0.11909731
#  1.2705761  1.2777034
# /Users/douglste/Dropbox/Models/UpSco_Mattea2015/UpSco_Mattea2015_00070Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.57435709
#     1.2012  1.6924892
# 0.28535998 0.96807293
#   0.582192 0.11909731
#  1.2705761  1.2777034
# /Users/douglste/Dropbox/Models/UpSco_Mattea2022/UpSco_Mattea2022_00070Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.57435709
#     1.2012  1.6924892
# 0.28535998 0.96807293
#   0.582192 0.11909731
#  1.2705761  1.2777034

# %%
for age in [303,525]:
    plt.figure()
    ax = plt.subplot(111)
#     plt.figure(figsize=(15,4))
    for i, model in enumerate(["ZeroTorque","Mattea2015","Mattea2022"]):
        modfile = os.path.join(mod_dir,f"UpSco_{model}/UpSco_{model}_{age:05d}Myr.txt")
        print(modfile)
        mod = at.read(modfile,names=["mass","period"])
        print(mod[:5])
#         _ = plot_periodcolor_histogram(clean_limit=0,to_plot_indiv=False,ax=ax)
        mod_bprp = mass_to_bp_rp(mod["mass"])
        ax.plot(mod_bprp,mod["period"],'*',ms=4,alpha=0.75,label=model)
#         ax.set_title(model)
    plt.suptitle(f"t = {age} Myr")
# Out:
# /Users/douglste/Dropbox/Models/UpSco_ZeroTorque/UpSco_ZeroTorque_00303Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.55775488
#     1.2012  2.9054658
# 0.28535998 0.91819524
#   0.582192 0.22082946
#  1.2705761  1.6703788
# /Users/douglste/Dropbox/Models/UpSco_Mattea2015/UpSco_Mattea2015_00303Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.55775488
#     1.2012  2.9054658
# 0.28535998 0.91819524
#   0.582192 0.22082946
#  1.2705761  1.6703788
# /Users/douglste/Dropbox/Models/UpSco_Mattea2022/UpSco_Mattea2022_00303Myr.txt
#    mass      period
# ---------- ----------
#    0.30328 0.55775488
#     1.2012  2.9054658
# 0.28535998 0.91819524
#   0.582192 0.22082946
#  1.2705761  1.6703788
# /Users/douglste/Dropbox/Models/UpSco_ZeroTorque/UpSco_ZeroTorque_00525Myr.txt
#    mass      period
# ---------- ----------
#    0.30328  0.8274375
#     1.2012  3.7218233
# 0.28535998  1.3499937
#   0.582192 0.47831131
#  1.2705761  1.9980474
# /Users/douglste/Dropbox/Models/UpSco_Mattea2015/UpSco_Mattea2015_00525Myr.txt
#    mass      period
# ---------- ----------
#    0.30328  0.8274375
#     1.2012  3.7218233
# 0.28535998  1.3499937
#   0.582192 0.47831131
#  1.2705761  1.9980474
# /Users/douglste/Dropbox/Models/UpSco_Mattea2022/UpSco_Mattea2022_00525Myr.txt
#    mass      period
# ---------- ----------
#    0.30328  0.8274375
#     1.2012  3.7218233
# 0.28535998  1.3499937
#   0.582192 0.47831131
#  1.2705761  1.9980474
